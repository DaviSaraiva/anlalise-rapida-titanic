# %%
import pandas as pd
import numpy as np

# %%
#1 questão
df = pd.read_csv('C:/Users/extra/Documents/titanic.csv')

# %%
#2 questão
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
#3 questão assim espero né
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
##3 quetão assim espero
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
##informação extra de quantos mulheres e quantos homens.
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
##informação extra de quantos sobreviveram e quantos não.
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
##informação extra vizualização dos que não sobreviveram 
df.query('Survived == 0').head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 16           17         0       3
# 18           19         0       3
# 20           21         0       2
# 24           25         0       3
# 26           27         0       3
# 27           28         0       1
# 29           30         0       3
# 30           31         0       1
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 37           38         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ...

# %%
##4 questão
filtro_df = df['Sex'] == 'female'
filtered_df= df[filtro_df]
filtered_df.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 14           15         0       3
# 15           16         1       2
# 18           19         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ...

# %%
##5.1 questão excluindo colunas name e Ticket
df_novo_excluidos = df.drop(df.columns[[3,8]],axis=1)
df_novo_excluidos
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0              1         0       3    male  22.0      1      0   7.2500   NaN
# 1              2         1       1  female  38.0      1      0  71.2833   C85
# 2              3         1       3  female  26.0      0      0   7.9250   NaN
# 3              4         1       1  female  35.0      1      0  53.1000  C123
# 4              5         0       3    male  35.0      0      0   8.0500   NaN
# ..           ...       ...     ...     ...   ...    ...    ...      ...   ...
# 886          887         0       2    male  27.0      0      0  13.0000   NaN
# 887          888         1       1  female  19.0      0      0  30.0000   B42
# 888          889         0       3  female   NaN      1      2  23.4500   NaN
# 889          890         1       1    male  26.0      0      0  30.0000  C148
# 890          891         0       3    male  32.0      0      0   7.7500   NaN
#
#     Embarked
# 0          S
# ...

# %%
##5.1 questão adicionando colunas exluidas em outro df
df_com_excluidos = df[['Name','Ticket']]

# %%
##5.2 20 primeiras
df_com_excluidos.head(20)
# Out:
#                                                  Name            Ticket
# 0                             Braund, Mr. Owen Harris         A/5 21171
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...          PC 17599
# 2                              Heikkinen, Miss. Laina  STON/O2. 3101282
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)            113803
# 4                            Allen, Mr. William Henry            373450
# 5                                    Moran, Mr. James            330877
# 6                             McCarthy, Mr. Timothy J             17463
# 7                      Palsson, Master. Gosta Leonard            349909
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            347742
# 9                 Nasser, Mrs. Nicholas (Adele Achem)            237736
# 10                    Sandstrom, Miss. Marguerite Rut           PP 9549
# 11                           Bonnell, Miss. Elizabeth            113783
# ...

# %%
##5.3 criar nova coluna com soma entre colunas
df['Tamanho_familia'] = df['SibSp']+ df['Parch']

# %%
##5.4 Imprima a nova coluna
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
##5.5 quais colunas apresentam valores inexistentes e quantos valores inexistente existe em cada coluna
##para retornar a soma dos valores nulos encontrados
df.isnull().sum()
# Out:
# PassengerId          0
# Survived             0
# Pclass               0
# Name                 0
# Sex                  0
# Age                177
# SibSp                0
# Parch                0
# Ticket               0
# Fare                 0
# Cabin              687
# Embarked             2
# Tamanho_familia      0
# dtype: int64

# %%
##5.6 Remova a coluna que apresenta mais valores inexistentes
## no caso o removido foi cabin/ cabine com 687 valores nulos encontrados
df_excluidos = df
df_excluidos_nulos=df_excluidos.drop(df.columns[[10]],axis=1)
df_excluidos_nulos.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
##5.7 Preencher as linhas relacionadas com a coluna Age que são NaN com a média das idades que temos no Dataset

mean_df = df_excluidos_nulos['Age'].mean()
print(mean_df)
# Out:
# 29.69911764705882

# %%
#depois subirtituir os NaN pela media
media_df=df_excluidos_nulos
media_NaN=media_df.fillna(media_df.mean())
media_NaN.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex        Age  \
# 0                             Braund, Mr. Owen Harris    male  22.000000
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# ...

# %%
##5.8 Utilizar a função MAP para mapear o sexo para o tipo inteiro male: 1 e female: 0  
zero_e_um = {
    'male': '1',
    'female': '2'
}
mapear = media_NaN
mapear['Sex'] = media_NaN.Sex.map(zero_e_um)
mapear.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name Sex        Age  SibSp  \
# 0                            Braund, Mr. Owen Harris   1  22.000000      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   2  38.000000      1
# 2                             Heikkinen, Miss. Laina   2  26.000000      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   2  35.000000      1
# 4                           Allen, Mr. William Henry   1  35.000000      0
# 5                                   Moran, Mr. James   1  29.699118      0
# ...

# %%
##5.9 Contar a quantidade de passageiros que Embarked = Southampton; Embarked = Cherbourg, Embarked = Cherbourg
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
##5.10 utilizar a função map para a categoria de Embarked {'S': 0, 'C': 1, 'Q': 2}
embar = {
    'S': '0',
    'C': '1',
    'Q': '2'
}
embarque = media_NaN
embarque['Embarked'] = media_NaN.Embarked.map(embar)
mapear.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name Sex        Age  SibSp  \
# 0                            Braund, Mr. Owen Harris   1  22.000000      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   2  38.000000      1
# 2                             Heikkinen, Miss. Laina   2  26.000000      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   2  35.000000      1
# 4                           Allen, Mr. William Henry   1  35.000000      0
# 5                                   Moran, Mr. James   1  29.699118      0
# ...
